# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from visualizer.main import Visualizer
from quadtree import Quadtree, Rectangle, Point

# %%
vis=Visualizer()
vis.add_point((5,5))
vis.show()

# %%
k = Quadtree(Rectangle(5,5,50,50),2)
